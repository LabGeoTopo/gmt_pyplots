# %%
## Import necessary modules
import pygmt
import pandas as pd
#pd.set_option('display.max_rows', None)

# %%
## Set input data file
## Format input file "Code Lat Long H Ve sVe Vn sN Vu sVu" with this header line
vel_df = pd.read_csv("data/velall.txt", sep=" ")
vel_df['vzero']=0
#vel = vel_df.head()
hvel = vel_df[['Long','Lat', 'Ve','Vn', 'sVe','sVn','sVu', 'Code']]
#hvel
vvel = vel_df[['Long','Lat', 'vzero','Vu', 'sVe','sVu','sVu', 'Code']]
#vvel
# Out:
#          Long       Lat  vzero     Vu  sVe  sVu  sVu  Code
# 0    25.71800  35.19150      0  -0.23  1.0  1.0  1.0  agni
# 1    26.26908  39.24645      0   2.14  0.0  0.0  0.0  agpa
# 2    21.40903  38.62399      0  -1.04  0.0  1.0  1.0  agr2
# 3    21.40784  38.62345      0   2.71  0.0  1.0  1.0  agri
# 4    23.12301  37.93861      0  16.53  1.0  3.0  3.0  agth
# ..        ...       ...    ...    ...  ...  ...  ...   ...
# 137  21.89926  37.43044      0   0.26  0.0  0.0  0.0  vass
# 138  20.58864  38.17683      0  -0.54  4.0  4.0  4.0  vlsm
# 139  22.76090  39.18081      0  -1.43  0.0  0.0  0.0  volo
# 140  24.85809  41.11481      0   1.48  1.0  0.0  0.0  xant
# 141  23.53270  35.31054      0   0.64  0.0  0.0  0.0  xrso
#
# [142 rows x 8 columns]

# %%
## Plot Horizontal velocities for each cite
fig = pygmt.Figure()
fig.basemap(region=[23, 24.5, 37.5, 38.5], projection="M15c", frame=True)
fig.coast(
    shorelines=True,
    land="grey",
    water="lightblue")
# store focal mechanisms parameters in a dict
# focal_mechanism = dict(strike=330, dip=30, rake=90, magnitude=3)

# pass the focal mechanism data to meca in addition to the scale and event
# location
# fig.meca(focal_mechanism, scale="1c", longitude=23.5, latitude=36, depth=12.0)

fig.plot(x=vel.Long, y=vel.Lat, style="c0.15c", color="black")

fig.velo(
    data=hvel,
    pen="0.7p,red",
    uncertaintycolor  ="lightblue1",
    line=True,
    spec="e0.05/0.39/11",
    frame=["WSne"],
    vector="0.35c+e+gred",
)

fig.show()

# %%
fig.savefig("vhor.png")

# %%
## Plot vertical velocities for each cite
fig = pygmt.Figure()
fig.basemap(region=[23, 24.5, 37.5, 38.5], projection="M15c", frame=True)
fig.coast(
    shorelines=True,
    land="grey",
    water="lightblue")


fig.plot(x=vel.Long, y=vel.Lat, style="c0.15c", color="black")

fig.velo(
    data=vel,
    pen="0.7p,red",
    uncertaintycolor  ="lightblue1",
    line=True,
    spec="e0.05/0.39/11",
    frame=["WSne"],
    vector="0.35c+e+gred",
)

fig.show()
